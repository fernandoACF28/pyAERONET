# %%
import pyAERO

# %%
list_vars =[
    'SIZ','RIN','SSA','SSA','ASY'
]

# %%
for k in list_vars:
    pyAERO.GetDataAEROET('Sao_Paulo','2002-02-01','2025-12-31',
                         k,inversion_type='ALM20',temporal_type='all')
# Out:
# ...
# Wait for 5.2 seconds...:   0%|          | 0/3 [00:00<?, ?it/s]
# Error! : cannot unpack non-iterable NoneType object
# ...
# Finish Download: 100%|██████████| 3/3 [00:10<00:00,  3.53s/it]
