# %% [markdown]
# ## Precisamos importar a biblioteca.

# %%
import pyAERO

# %% [markdown]
# `pyAERO` é uma classe que contém funções.
# A função para download é
# `GetDataAEROET`

# %%
pyAERO.GetDataAEROET(station='Sao_Paulo',start_date='2010-10-10',
                     end_date='2012-10-10',
                     vars='AOD20',
                     temporal_type='ALL',
                     user_name='fernando.allysson@usp.br')
# Out:
# Finish Download: 100%|██████████| 3/3 [00:09<00:00,  3.19s/it]
